# %%
from simulate import simulate
from argparse import Namespace
from pathlib import Path

# %%
def simulate_function(input_file, output_file, result_file="results.json", strategy="balanced"):
    """Call simulate with a complete Namespace
    input_file: Path to scenario json as String
    """
    params = Namespace(input=input_file, strategy=strategy, margin=1,
                       strategy_option=[("allow_negative_soc", True)], visual=False,
                       save_timeseries=output_file, save_results=result_file, config=None, eta=False)
    simulate(params)

# %%
# set SpiceEV scenario directory
dirs = Path("workshop_data", "scenario_1")
region_list = [f.stem for f in dirs.rglob("*.json")]
# set charging strategy
strat = "balanced"
result_dir = Path(dirs, "res_" + strat)
result_dir.mkdir(exist_ok=True)
for counter, regio in enumerate(region_list):
    simulate_function(Path(dirs, regio + ".json"), str(Path(result_dir, regio + ".csv")), strategy=strat)
    print("Region {} done! ({}/{})".format(regio, counter+1, len(region_list)))
# Out:
# Warning: SOC of vehicle phev_mini_00003_standing_t became negative at 2021-01-12 13:15:00+01:00. SOC is -0.009921036794932864, continuing with SOC = 0
# Warning: SOC of vehicle phev_mini_00002_standing_t became negative at 2021-01-12 19:15:00+01:00. SOC is -0.026439055136272205, continuing with SOC = 0
# Warning: SOC of vehicle phev_medium_00003_standing_t became negative at 2021-01-13 05:00:00+01:00. SOC is -0.010789355892314223, continuing with SOC = 0
# Warning: SOC of vehicle phev_medium_00009_standing_t became negative at 2021-01-15 06:15:00+01:00. SOC is -0.013760224117458586, continuing with SOC = 0
# Warning: SOC of vehicle phev_mini_00001_standing_t became negative at 2021-01-15 12:45:00+01:00. SOC is -0.013224715676352028, continuing with SOC = 0
# Energy drawn from grid: 4159 kWh, Costs: 6.25 €
# Region LR_Klein done! (1/7)
# Warning: 1 events ignored after end of scenario
# Warning: SOC of vehicle phev_luxury_00001_standing_t became negative at 2021-01-07 08:45:00+01:00. SOC is -1.7865897689595123e-05, continuing with SOC = 0
# Warning: SOC of vehicle phev_luxury_00005_standing_t became negative at 2021-01-09 12:00:00+01:00. SOC is -0.01834319245020538, continuing with SOC = 0
# Warning: SOC of vehicle phev_luxury_00006_standing_t became negative at 2021-01-11 08:45:00+01:00. SOC is -0.009166816155115748, continuing with SOC = 0
# Warning: SOC of vehicle phev_luxury_00005_standing_t became negative at 2021-01-14 13:30:00+01:00. SOC is -0.04125067269802074, continuing with SOC = 0
# Warning: SOC of vehicle phev_medium_00000_standing_t became negative at 2021-01-14 23:45:00+01:00. SOC is -0.013756772819067509, continuing with SOC = 0
# Warning: SOC of vehicle phev_luxury_00006_standing_t became negative at 2021-01-15 06:45:00+01:00. SOC is -0.016130449404032743, continuing with SOC = 0
# Warning: SOC of vehicle phev_medium_00001_standing_t became negative at 2021-01-16 17:45:00+01:00. SOC is -3.540648765587573e-05, continuing with SOC = 0
# Energy drawn from grid: 9565 kWh, Costs: 14.28 €
# Warning: 1 events ignored after end of scenario
# Region LR_Mitte done! (2/7)
# Warning: SOC of vehicle phev_mini_00000_standing_t became negative at 2021-01-15 17:45:00+01:00. SOC is -0.001856237784809367, continuing with SOC = 0
# Warning: SOC of vehicle phev_luxury_00003_standing_t became negative at 2021-01-16 09:15:00+01:00. SOC is -0.0005902254591211298, continuing with SOC = 0
# Energy drawn from grid: 3157 kWh, Costs: 4.78 €
# Region LR_Zentr done! (3/7)
# Warning: SOC of vehicle phev_mini_00005_standing_t became negative at 2021-01-08 21:15:00+01:00. SOC is -0.04956424101761381, continuing with SOC = 0
# Warning: SOC of vehicle phev_mini_00003_standing_t became negative at 2021-01-10 19:15:00+01:00. SOC is -0.016528395284274355, continuing with SOC = 0
# Warning: SOC of vehicle phev_mini_00009_standing_t became negative at 2021-01-13 21:00:00+01:00. SOC is -0.016520085763923942, continuing with SOC = 0
# Energy drawn from grid: 3167 kWh, Costs: 4.76 €
# Region SR_Gross done! (4/7)
# Warning: SOC of vehicle phev_mini_00007_standing_t became negative at 2021-01-06 07:15:00+01:00. SOC is -0.003509908444131904, continuing with SOC = 0
# Warning: SOC of vehicle phev_luxury_00004_standing_t became negative at 2021-01-06 14:45:00+01:00. SOC is -0.009166816155115748, continuing with SOC = 0
# Warning: SOC of vehicle phev_luxury_00006_standing_t became negative at 2021-01-09 10:15:00+01:00. SOC is -0.009166816155115748, continuing with SOC = 0
# Energy drawn from grid: 2476 kWh, Costs: 3.67 €
# Region SR_Klein done! (5/7)
# Warning: 2 events ignored after end of scenario
# Warning: SOC of vehicle phev_medium_00011_standing_t became negative at 2021-01-05 18:15:00+01:00. SOC is -0.013750224232673691, continuing with SOC = 0
# Warning: SOC of vehicle phev_medium_00001_standing_t became negative at 2021-01-07 09:45:00+01:00. SOC is -0.01375022423267358, continuing with SOC = 0
# Warning: SOC of vehicle phev_mini_00017_standing_t became negative at 2021-01-07 20:30:00+01:00. SOC is -0.009920931458473226, continuing with SOC = 0
# Warning: SOC of vehicle phev_luxury_00019_standing_t became negative at 2021-01-09 13:45:00+01:00. SOC is -0.009166816155115748, continuing with SOC = 0
# Warning: SOC of vehicle phev_mini_00009_standing_t became negative at 2021-01-09 18:00:00+01:00. SOC is -0.01983033424726699, continuing with SOC = 0
# Warning: SOC of vehicle phev_medium_00013_standing_t became negative at 2021-01-10 00:15:00+01:00. SOC is -0.005137611750376081, continuing with SOC = 0
# Warning: SOC of vehicle phev_medium_00009_standing_t became negative at 2021-01-10 12:15:00+01:00. SOC is -0.006353570884787052, continuing with SOC = 0
# Warning: SOC of vehicle phev_medium_00006_standing_t became negative at 2021-01-10 20:30:00+01:00. SOC is -0.01747858982928918, continuing with SOC = 0
# Warning: SOC of vehicle phev_mini_00028_standing_t became negative at 2021-01-11 11:00:00+01:00. SOC is -0.0003156656388890733, continuing with SOC = 0
# Warning: SOC of vehicle phev_medium_00010_standing_t became negative at 2021-01-11 18:15:00+01:00. SOC is -0.04126067231320296, continuing with SOC = 0
# Warning: SOC of vehicle phev_luxury_00012_standing_t became negative at 2021-01-12 00:00:00+01:00. SOC is -0.004635150839470678, continuing with SOC = 0
# Warning: SOC of vehicle phev_mini_00011_standing_t became negative at 2021-01-12 00:00:00+01:00. SOC is -0.016518395883696357, continuing with SOC = 0
# Warning: SOC of vehicle phev_luxury_00002_standing_t became negative at 2021-01-12 08:15:00+01:00. SOC is -0.009175660460056356, continuing with SOC = 0
# Warning: SOC of vehicle phev_luxury_00002_standing_t became negative at 2021-01-12 13:30:00+01:00. SOC is -0.018333632310231496, continuing with SOC = 0
# Warning: SOC of vehicle phev_medium_00018_standing_t became negative at 2021-01-12 21:15:00+01:00. SOC is -0.00012621971474879867, continuing with SOC = 0
# Warning: SOC of vehicle phev_mini_00014_standing_t became negative at 2021-01-13 11:00:00+01:00. SOC is -0.00660735835347856, continuing with SOC = 0
# Warning: SOC of vehicle phev_mini_00008_standing_t became negative at 2021-01-13 17:15:00+01:00. SOC is -0.02643943340020427, continuing with SOC = 0
# Warning: SOC of vehicle phev_mini_00005_standing_t became negative at 2021-01-14 10:00:00+01:00. SOC is -0.006617143989877172, continuing with SOC = 0
# Warning: SOC of vehicle phev_mini_00022_standing_t became negative at 2021-01-14 14:30:00+01:00. SOC is -0.01322447968352386, continuing with SOC = 0
# Warning: SOC of vehicle phev_medium_00018_standing_t became negative at 2021-01-14 18:15:00+01:00. SOC is -0.00012620823351017219, continuing with SOC = 0
# Warning: SOC of vehicle phev_luxury_00019_standing_t became negative at 2021-01-15 12:00:00+01:00. SOC is -0.009166816155115748, continuing with SOC = 0
# Warning: SOC of vehicle phev_medium_00009_standing_t became negative at 2021-01-15 15:30:00+01:00. SOC is -0.00012620823351017219, continuing with SOC = 0
# Warning: SOC of vehicle phev_medium_00010_standing_t became negative at 2021-01-15 19:15:00+01:00. SOC is -0.013750224232673691, continuing with SOC = 0
# Warning: SOC of vehicle phev_luxury_00001_standing_t became negative at 2021-01-16 13:00:00+01:00. SOC is -0.04583797883987384, continuing with SOC = 0
# Warning: SOC of vehicle phev_mini_00014_standing_t became negative at 2021-01-17 11:15:00+01:00. SOC is -0.009911037530217853, continuing with SOC = 0
# Warning: SOC of vehicle phev_mini_00023_standing_t became negative at 2021-01-17 16:45:00+01:00. SOC is -0.009919314984079275, continuing with SOC = 0
# Energy drawn from grid: 14436 kWh, Costs: 21.23 €
# Warning: 2 events ignored after end of scenario
# Region SR_Metro done! (6/7)
# Warning: 1 events ignored after end of scenario
# Warning: SOC of vehicle phev_luxury_00010_standing_t became negative at 2021-01-06 21:15:00+01:00. SOC is -0.0001166728033207276, continuing with SOC = 0
# Warning: SOC of vehicle phev_luxury_00011_standing_t became negative at 2021-01-07 18:15:00+01:00. SOC is -0.00916681615511572, continuing with SOC = 0
# Warning: SOC of vehicle phev_mini_00000_standing_t became negative at 2021-01-11 07:00:00+01:00. SOC is -0.013224716690361404, continuing with SOC = 0
# Warning: SOC of vehicle phev_mini_00008_standing_t became negative at 2021-01-11 09:30:00+01:00. SOC is -0.01982207506043565, continuing with SOC = 0
# Warning: SOC of vehicle phev_luxury_00004_standing_t became negative at 2021-01-12 02:30:00+01:00. SOC is -0.001141671721006321, continuing with SOC = 0
# Warning: SOC of vehicle phev_medium_00009_standing_t became negative at 2021-01-12 15:00:00+01:00. SOC is -0.002711296182021816, continuing with SOC = 0
# Warning: SOC of vehicle phev_medium_00009_standing_t became negative at 2021-01-12 22:30:00+01:00. SOC is -0.02062533634901048, continuing with SOC = 0
# Warning: SOC of vehicle phev_medium_00016_standing_t became negative at 2021-01-13 17:15:00+01:00. SOC is -0.00044132532039198313, continuing with SOC = 0
# Warning: SOC of vehicle phev_medium_00010_standing_t became negative at 2021-01-14 06:30:00+01:00. SOC is -5.490881001057879e-05, continuing with SOC = 0
# Warning: SOC of vehicle phev_mini_00005_standing_t became negative at 2021-01-14 06:45:00+01:00. SOC is -0.016528395872784374, continuing with SOC = 0
# Warning: SOC of vehicle phev_medium_00005_standing_t became negative at 2021-01-15 09:30:00+01:00. SOC is -0.004401196608591285, continuing with SOC = 0
# Warning: SOC of vehicle phev_luxury_00011_standing_t became negative at 2021-01-15 17:30:00+01:00. SOC is -0.007624830814256911, continuing with SOC = 0
# Warning: SOC of vehicle phev_mini_00006_standing_t became negative at 2021-01-16 10:30:00+01:00. SOC is -0.0021778586389196164, continuing with SOC = 0
# Energy drawn from grid: 11124 kWh, Costs: 16.69 €
# Warning: 1 events ignored after end of scenario
# Region SR_Mitte done! (7/7)
