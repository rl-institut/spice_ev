# %% [markdown]
# # Anwendung und Vergleich von Ladestrategien

# %% [markdown]
# ### Erstellen eines synthetischen Fuhrparks durch generate.py

# %%
# Anpassen der Konfigurationen und Erstellen der Fahrprofile

# %% [markdown]
# ### Einbinden von SimBEV-Fahrprofilen durch generate_from_simbev.py

# %%
# Ordner mit Fahrprofilen anlegen und einbinden

# %% [markdown]
# ### Aufbau einer Ladestrategie am Beispiel "greedy"
